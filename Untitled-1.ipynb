# %%
import pandas as pd
import os

# %%
df = pd.read_csv("res/preprocessed_data/master.csv")
df
# Out:
#        Unnamed: 0        DATE     CC   Q_CC      DATE.1     FG   Q_FG  \
# 0               0  01/09/1957    8.0    0.0  01/09/1957   21.0    0.0
# 1               1  02/09/1957    6.0    0.0  02/09/1957   32.0    0.0
# 2               2  03/09/1957    6.0    0.0  03/09/1957   16.0    0.0
# 3               3  04/09/1957    7.0    0.0  04/09/1957   16.0    0.0
# 4               4  05/09/1957    7.0    0.0  05/09/1957   28.0    0.0
# ...           ...         ...    ...    ...         ...    ...    ...
# 24589       24589         NaN    NaN    NaN         NaN    NaN    NaN
# 24590       24590         NaN    NaN    NaN         NaN    NaN    NaN
# 24591       24591         NaN    NaN    NaN         NaN    NaN    NaN
# 24592       24592         NaN    NaN    NaN         NaN    NaN    NaN
# 24593       24593         NaN    NaN    NaN         NaN    NaN    NaN
#
#            DATE.2     FX   Q_FX  ...  Q_SS      DATE.9     TG  Q_TG  \
# ...

# %%
df.columns = [i.strip() for i in df.columns]

# %%
df['CC'].value_counts()
